# %%
from simulator import Simulator
from turbStats import tilt_mat, corr_mat, get_r0
import matplotlib.pyplot as plt
import torch
import os

import numpy as np
import cv2

# %%
# 运动模糊
# Select device.
device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('CPU')


# Uncomment the following line to generate correlation matrix
# corr_mat(-0.1,'./data/')

# Load image, permute axis if color
folder_img = "D:\\All_Datasets\\WHUbuilding\\WHU building\\train\\A_0_x2\\"
folder_save = "D:\\All_Datasets\\WHUbuilding\\WHU building\\train\\A_0_x2_motion\\"

list_imgname = os.listdir(folder_img)

for name in list_imgname:
    img = folder_img+name
    img = plt.imread(img)
    motioned_image = motion_blur(img)
    
    # 确保目标文件夹存在，如果不存在则创建
    if not os.path.exists(folder_save):
        os.makedirs(folder_save)
    plt.imsave(folder_save+name, motioned_image)
    print(folder_save+name)
print("完事")
# Out:
# D:\All_Datasets\WHUbuilding\WHU building\train\A_0_x2_motion\100.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_0_x2_motion\1000.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_0_x2_motion\1003.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_0_x2_motion\1005.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_0_x2_motion\1006.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_0_x2_motion\1008.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_0_x2_motion\1012.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_0_x2_motion\1014.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_0_x2_motion\1016.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_0_x2_motion\1017.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_0_x2_motion\1018.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_0_x2_motion\1020.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_0_x2_motion\1025.png
# ...

# %%
# 大气湍流模糊
# Select device.
device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('CPU')


# Uncomment the following line to generate correlation matrix
# corr_mat(-0.1,'./data/')

# Load image, permute axis if color
# folder_img = "D:\\All_Datasets\\WHUbuilding\\WHU building\\train\\A_0_x4\\"
# folder_save = "D:\\All_Datasets\\WHUbuilding\\WHU building\\train\\A_0_x4_at\\"
folder_img = "D:\\All_Datasets\\WHUbuilding\\WHU building\\train\\A_1_x2\\"
folder_save = "D:\\All_Datasets\\WHUbuilding\\WHU building\\train\\A_1_x2_at\\"
    
list_imgname = os.listdir(folder_img)

for name in list_imgname:
    img = folder_img+name
    img = plt.imread(img)
#     distorted_image = atmospheric_blur(img).clip(0, 255).astype(np.uint8)
    distorted_image = atmospheric_blur(img)
    
    # 确保目标文件夹存在，如果不存在则创建
    if not os.path.exists(folder_save):
        os.makedirs(folder_save)
    plt.imsave(folder_save+name, distorted_image)
    print(folder_save+name)
print("完事")
# Out:
# D:\All_Datasets\WHUbuilding\WHU building\train\A_1_x2_at\0.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_1_x2_at\1.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_1_x2_at\10.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_1_x2_at\1002.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_1_x2_at\1007.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_1_x2_at\1009.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_1_x2_at\101.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_1_x2_at\1011.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_1_x2_at\1013.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_1_x2_at\1015.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_1_x2_at\1019.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_1_x2_at\102.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_1_x2_at\1021.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_1_x2_at\1022.png
# ...

# %%
# 运动模糊＋大气湍流模糊
# Select device.
device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('CPU')


# Uncomment the following line to generate correlation matrix
# corr_mat(-0.1,'./data/')

# Load image, permute axis if color
folder_img = "D:\\All_Datasets\\WHUbuilding\\WHU building\\train\\A_2_x2\\"
folder_save = "D:\\All_Datasets\\WHUbuilding\\WHU building\\train\\A_2_x2_at\\"
list_imgname = os.listdir(folder_img)
for name in list_imgname:
    img = folder_img+name
    img = plt.imread(img)
#     distorted_image = atmospheric_blur(img).clip(0, 255).astype(np.uint8)
    distorted_image = atmospheric_blur(img)
    
    # 确保目标文件夹存在，如果不存在则创建
    if not os.path.exists(folder_save):
        os.makedirs(folder_save)
    plt.imsave(folder_save+name, distorted_image)
    print(folder_save+name)
print("//////////////////大气模糊完事//////////")

folder_img = "D:\\All_Datasets\\WHUbuilding\\WHU building\\train\\A_2_x2_at\\"
folder_save = "D:\\All_Datasets\\WHUbuilding\\WHU building\\train\\A_2_x2_atmo\\"
    
list_imgname = os.listdir(folder_img)
for name in list_imgname:
    img = folder_img+name
    img = plt.imread(img)
    motioned_image = motion_blur(img)
    
    # 确保目标文件夹存在，如果不存在则创建
    if not os.path.exists(folder_save):
        os.makedirs(folder_save)
    plt.imsave(folder_save+name, motioned_image)
    print(folder_save+name)
print("////////////模糊完事////////////")
# Out:
# D:\All_Datasets\WHUbuilding\WHU building\train\A_2_x2_at\1001.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_2_x2_at\1004.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_2_x2_at\1010.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_2_x2_at\1024.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_2_x2_at\1027.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_2_x2_at\103.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_2_x2_at\1049.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_2_x2_at\105.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_2_x2_at\1050.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_2_x2_at\1069.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_2_x2_at\1073.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_2_x2_at\1080.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_2_x2_at\1084.png
# D:\All_Datasets\WHUbuilding\WHU building\train\A_2_x2_at\1085.png
# ...

# %%
# 运动模糊＋大气湍流模糊
# Select device.
device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('CPU')


# Uncomment the following line to generate correlation matrix
# corr_mat(-0.1,'./data/')

# Load image, permute axis if color
folder_img = "D:\\All_Datasets\\WHUbuilding\\WHU building\\train\\A_2_x4\\"
folder_save = "D:\\All_Datasets\\WHUbuilding\\WHU building\\train\\A_2_x4_moat\\"
    
list_imgname = os.listdir(folder_img)

for name in list_imgname:
    img = folder_img+name
    img = plt.imread(img)
    motioned_image = motion_blur(img)
    distorted_motioned_image = atmospheric_blur(motioned_image)
    
    # 确保目标文件夹存在，如果不存在则创建
    if not os.path.exists(folder_save):
        os.makedirs(folder_save)
    plt.imsave(folder_save+name, distorted_motioned_image)
    print(folder_save+name)
print("完事")
def atmospheric_blur(img):
    x = img
    if len(x.shape) == 3: 
        x = x.transpose((2,0,1))
    x = torch.tensor(x, device = device, dtype=torch.float32)

    D = 0.1
    L = 3000
    # r0 can also be calculated from Cn2 and L using the get_r0 function: 
    # r0 = get_r0(Cn2, L)
    r0 = 0.125

    im_size = x.shape[1] # The current version works for square image only

    # Generate correlation matrix for tilt. Do this once for each different turbulence parameter. 
    tilt_mat(im_size, D, r0, L)

    # Simulate. 
    simulator = Simulator(D/r0, im_size).to(device, dtype=torch.float32)

    # Note that the current version does not support batched images. Only one frame at a time. 
    out = simulator(x).detach().cpu().numpy()

    if len(out.shape) == 3: 
        out = out.transpose((1,2,0))
#     out = np.array(np.clip(out,0,1)*255, dtype=np.uint8)
    return out
#     plt.imsave(folder_save+imgname,out)
def motion_blur(image, degree=6, angle=45):
    image = np.array(image)

    # 这里生成任意角度的运动模糊kernel的矩阵， degree越大，模糊程度越高
    M = cv2.getRotationMatrix2D((degree / 2, degree / 2), angle, 1)
    motion_blur_kernel = np.diag(np.ones(degree))
    motion_blur_kernel = cv2.warpAffine(motion_blur_kernel, M, (degree, degree))

    motion_blur_kernel = motion_blur_kernel / degree
    blurred = cv2.filter2D(image, -1, motion_blur_kernel)

    # convert to uint8
    cv2.normalize(blurred, blurred, 0, 255, cv2.NORM_MINMAX)
    blurred = np.array(blurred, dtype=np.uint8)
    return blurred
